# %% [markdown]
# # Read CSV Files and Some Operations on csv files

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', nrows=10)      # Print only first 10 rows
df
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', usecols=[0,1,4,5,6])     # Print Some specific Columns
df
# Out:
#      gender race/ethnicity test preparation course  math score  reading score
# 0    female        group B                    none          72             72
# 1    female        group C               completed          69             90
# 2    female        group B                    none          90             95
# 3      male        group A                    none          47             57
# 4      male        group C                    none          76             78
# 5    female        group B                    none          71             83
# 6    female        group B               completed          88             95
# 7      male        group B                    none          40             43
# 8      male        group D               completed          64             64
# 9    female        group B                    none          38             60
# 10     male        group C                    none          58             54
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', skiprows=[0,1,5,6])  # Skip some specific rows
df
# Out:
#      female  group C        some college      standard  completed  69   90  \
# 0    female  group B     master's degree      standard       none  90   95
# 1      male  group A  associate's degree  free/reduced       none  47   57
# 2    female  group B        some college      standard  completed  88   95
# 3      male  group B        some college  free/reduced       none  40   43
# 4      male  group D         high school  free/reduced  completed  64   64
# 5    female  group B         high school  free/reduced       none  38   60
# 6      male  group C  associate's degree      standard       none  58   54
# 7      male  group D  associate's degree      standard       none  40   52
# 8    female  group B         high school      standard       none  65   81
# 9      male  group A        some college      standard  completed  78   72
# 10   female  group A     master's degree      standard       none  50   53
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', index_col='reading score') # Make columns to an Index
df
# Out:
#                gender race/ethnicity parental level of education  \
# reading score
# 72             female        group B           bachelor's degree
# 90             female        group C                some college
# 95             female        group B             master's degree
# 57               male        group A          associate's degree
# 78               male        group C                some college
# 83             female        group B          associate's degree
# 95             female        group B                some college
# 43               male        group B                some college
# 64               male        group D                 high school
# 60             female        group B                 high school
# 54               male        group C          associate's degree
# 52               male        group D          associate's degree
# 81             female        group B                 high school
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', header=1)      # Change header i.e. skip top row
df
# Out:
#      female  group B   bachelor's degree      standard       none  72  72.1  \
# 0    female  group C        some college      standard  completed  69    90
# 1    female  group B     master's degree      standard       none  90    95
# 2      male  group A  associate's degree  free/reduced       none  47    57
# 3      male  group C        some college      standard       none  76    78
# 4    female  group B  associate's degree      standard       none  71    83
# 5    female  group B        some college      standard  completed  88    95
# 6      male  group B        some college  free/reduced       none  40    43
# 7      male  group D         high school  free/reduced  completed  64    64
# 8    female  group B         high school  free/reduced       none  38    60
# 9      male  group C  associate's degree      standard       none  58    54
# 10     male  group D  associate's degree      standard       none  40    52
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', header=None, prefix='Col ') # Change header to any name
df
# Out:
#        Col 0           Col 1                        Col 2         Col 3  \
# 0     gender  race/ethnicity  parental level of education         lunch
# 1     female         group B            bachelor's degree      standard
# 2     female         group C                 some college      standard
# 3     female         group B              master's degree      standard
# 4       male         group A           associate's degree  free/reduced
# 5       male         group C                 some college      standard
# 6     female         group B           associate's degree      standard
# 7     female         group B                 some college      standard
# 8       male         group B                 some college  free/reduced
# 9       male         group D                  high school  free/reduced
# 10    female         group B                  high school  free/reduced
# 11      male         group C           associate's degree      standard
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', names=['a','b','c','f','t','u', 'y','p']) # Give heading name 
df
# Out:
#            a               b                            c             f  \
# 0     gender  race/ethnicity  parental level of education         lunch
# 1     female         group B            bachelor's degree      standard
# 2     female         group C                 some college      standard
# 3     female         group B              master's degree      standard
# 4       male         group A           associate's degree  free/reduced
# 5       male         group C                 some college      standard
# 6     female         group B           associate's degree      standard
# 7     female         group B                 some college      standard
# 8       male         group B                 some college  free/reduced
# 9       male         group D                  high school  free/reduced
# 10    female         group B                  high school  free/reduced
# 11      male         group C           associate's degree      standard
# ...

# %%
df.head(50)
# Out:
#          a               b                            c             f  \
# 0   gender  race/ethnicity  parental level of education         lunch
# 1   female         group B            bachelor's degree      standard
# 2   female         group C                 some college      standard
# 3   female         group B              master's degree      standard
# 4     male         group A           associate's degree  free/reduced
# 5     male         group C                 some college      standard
# 6   female         group B           associate's degree      standard
# 7   female         group B                 some college      standard
# 8     male         group B                 some college  free/reduced
# 9     male         group D                  high school  free/reduced
# 10  female         group B                  high school  free/reduced
# 11    male         group C           associate's degree      standard
# ...

# %%
df.tail(50)
# Out:
#            a        b                   c             f          t    u    y  \
# 951     male  group E         high school      standard       none   94   73
# 952   female  group D        some college      standard  completed   75   77
# 953   female  group E    some high school  free/reduced       none   74   74
# 954     male  group C         high school      standard  completed   58   52
# 955   female  group C        some college      standard       none   62   69
# 956     male  group E  associate's degree      standard       none   72   57
# 957     male  group C        some college      standard       none   84   87
# 958   female  group D     master's degree      standard       none   92  100
# 959   female  group D         high school      standard       none   45   63
# 960     male  group C         high school      standard       none   75   81
# 961   female  group A        some college      standard       none   56   58
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\StudentsPerformance.csv', true_values=['gender'])
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df=pd.read_csv('D:\\Pyhton\\dataset\\2017.csv')
df
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# 5                 Netherlands               6            7.377      7.427426
# 6                      Canada               7            7.316      7.384403
# 7                 New Zealand               8            7.314      7.379510
# 8                      Sweden               9            7.284      7.344095
# 9                   Australia              10            7.284      7.356651
# 10                     Israel              11            7.213      7.279853
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df.columns[0:5]
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low'],
#       dtype='object')

# %%
df.head()
# Out:
#     Col 0           Col 1                        Col 2         Col 3  \
# 0  gender  race/ethnicity  parental level of education         lunch
# 1  female         group B            bachelor's degree      standard
# 2  female         group C                 some college      standard
# 3  female         group B              master's degree      standard
# 4    male         group A           associate's degree  free/reduced
#
#                      Col 4       Col 5          Col 6          Col 7
# 0  test preparation course  math score  reading score  writing score
# 1                     none          72             72             74
# 2                completed          69             90             88
# 3                     none          90             95             93
# 4                     none          47             57             44

# %%
df.tail()
# Out:
#        Col 0    Col 1            Col 2         Col 3      Col 4 Col 5 Col 6  \
# 996   female  group E  master's degree      standard  completed    88    99
# 997     male  group C      high school  free/reduced       none    62    55
# 998   female  group C      high school  free/reduced  completed    59    71
# 999   female  group D     some college      standard  completed    68    78
# 1000  female  group D     some college  free/reduced       none    77    86
#
#      Col 7
# 996     95
# 997     55
# 998     65
# 999     77
# 1000    86
